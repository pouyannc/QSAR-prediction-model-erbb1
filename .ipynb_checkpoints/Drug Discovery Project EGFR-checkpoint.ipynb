# %% [markdown]
# # Computational Drug Discovery Project
#
# Pouyan Chamanian
#
# We will use bioactivity data for Epidermal Growth Factor Receptor (EGFR) from the chEMBL database

# %%
! pip install panda
! pip install chembl_webresource_client
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\site-packages (from panda) (58.1.0)
# Requirement already satisfied: requests in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from panda) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->panda) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->panda) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->panda) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->panda) (2.0.12)
# Using legacy 'setup.py install' for panda, since package 'wheel' is not installed.
# Installing collected packages: panda
#   Running setup.py install for panda: started
#   Running setup.py install for panda: finished with status 'done'
# Successfully installed panda-0.3.1
# Requirement already satisfied: chembl_webresource_client in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.10.7)
# Requirement already satisfied: requests-cache~=0.7.0 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: urllib3 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from chembl_webresource_client) (1.26.9)
# Requirement already satisfied: requests>=2.18.4 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from chembl_webresource_client) (2.27.1)
# Requirement already satisfied: easydict in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: six in c:\users\pouyan\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# Target Search

# %%
#Searching for EGFR in all targets
target_query = new_client.target.search("EGFR")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'Q01279', 'xref_name': None, 'xre...  Mus musculus
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3  [{'xref_id': 'P00533', 'xref_name': None, 'xre...  Homo sapiens
# 4                                                 []  Homo sapiens
# 5                                                 []  Homo sapiens
# 6                                                 []  Homo sapiens
# 7                                                 []  Homo sapiens
# 8                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0             Epidermal growth factor receptor erbB1   16.0
# 1                                        EGFR/PPP1CA   16.0
# 2                                           VHL/EGFR   16.0
# 3             Epidermal growth factor receptor erbB1   12.0
# 4  Protein cereblon/Epidermal growth factor receptor   11.0
# 5  MER intracellular domain/EGFR extracellular do...    9.0
# 6  Epidermal growth factor receptor and ErbB2 (HE...    7.0
# 7  Baculoviral IAP repeat-containing protein 2/Ep...    7.0
# 8                   Epidermal growth factor receptor    5.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL3608
# 1               False    CHEMBL4523747
# 2               False    CHEMBL4523998
# 3               False        CHEMBL203
# 4               False    CHEMBL4523680
# 5               False    CHEMBL3137284
# 6               False    CHEMBL2111431
# 7               False    CHEMBL4802031
# 8               False    CHEMBL2363049
#
#                                    target_components  \
# 0  [{'accession': 'Q01279', 'component_descriptio...
# 1  [{'accession': 'P00533', 'component_descriptio...
# 2  [{'accession': 'P00533', 'component_descriptio...
# 3  [{'accession': 'P00533', 'component_descriptio...
# 4  [{'accession': 'P00533', 'component_descriptio...
# 5  [{'accession': 'P00533', 'component_descriptio...
# 6  [{'accession': 'P04626', 'component_descriptio...
# 7  [{'accession': 'P00533', 'component_descriptio...
# 8  [{'accession': 'P04626', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3               SINGLE PROTEIN    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606
# 5             CHIMERIC PROTEIN    9606
# 6               PROTEIN FAMILY    9606
# 7  PROTEIN-PROTEIN INTERACTION    9606
# 8               PROTEIN FAMILY    9606

# %%
#choosing the EGFR erbB1 single protein as our target
target_id = targets.target_chembl_id[3]
target_id
# Out:
# 'CHEMBL203'

# %%
#filter for IC50 values
res = new_client.activity.filter(target_chembl_id=target_id)

# %%
df = pd.DataFrame.from_dict(res)

# %%
pd.set_option('display.max_columns', None)
df.head(4)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        32260                  []    CHEMBL674637
# 1             None        32263                  []    CHEMBL621151
# 2             None        32265                  []    CHEMBL615325
# 3             None        32267                  []    CHEMBL674637
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity towards tyrosine phosphory...          B
# 1  Inhibition of autophosphorylation of human epi...          F
# 2  Inhibition of ligand-induced proliferation in ...          F
# 3  Inhibitory activity towards tyrosine phosphory...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000219
# 2                    None                   None  BAO_0000190  BAO_0000219
# 3                    None                   None  BAO_0000190  BAO_0000357
#
#                bao_label                                   canonical_smiles  \
# 0  single protein format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1      cell-based format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2      cell-based format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3  single protein format  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
#
#   data_validity_comment data_validity_description document_chembl_id  \
# 0                  None                      None      CHEMBL1134862
# 1                  None                      None      CHEMBL1134862
# 2                  None                      None      CHEMBL1134862
# 3                  None                      None      CHEMBL1134862
#
#            document_journal  document_year  \
# 0  Bioorg. Med. Chem. Lett.         2002.0
# 1  Bioorg. Med. Chem. Lett.         2002.0
# 2  Bioorg. Med. Chem. Lett.         2002.0
# 3  Bioorg. Med. Chem. Lett.         2002.0
#
#                                    ligand_efficiency molecule_chembl_id  \
# 0  {'bei': '19.25', 'le': '0.37', 'lle': '2.94', ...        CHEMBL68920
# 1                                               None        CHEMBL68920
# 2                                               None        CHEMBL68920
# 3  {'bei': '14.02', 'le': '0.27', 'lle': '3.16', ...        CHEMBL69960
#
#   molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0               None               CHEMBL68920          7.39
# 1               None               CHEMBL68920          6.52
# 2               None               CHEMBL68920          5.11
# 3               None               CHEMBL69960          6.77
#
#    potential_duplicate                                 qudt_units  record_id  \
# 0                False  http://www.openphacts.org/units/Nanomolar     119482
# 1                False  http://www.openphacts.org/units/Nanomolar     119482
# 2                False  http://www.openphacts.org/units/Nanomolar     119482
# 3                False  http://www.openphacts.org/units/Nanomolar     119494
#
#   relation  src_id  standard_flag standard_relation standard_text_value  \
# 0        =       1           True                 =                None
# 1        =       1           True                 =                None
# 2        =       1           True                 =                None
# 3        =       1           True                 =                None
#
#   standard_type standard_units standard_upper_value standard_value  \
# 0          IC50             nM                 None           41.0
# 1          IC50             nM                 None          300.0
# 2          IC50             nM                 None         7820.0
# 3          IC50             nM                 None          170.0
#
#   target_chembl_id target_organism                        target_pref_name  \
# 0        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 1        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 2        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 3        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
#
#   target_tax_id text_value  toid  type units    uo_units upper_value  value
# 0          9606       None  None  IC50    uM  UO_0000065        None  0.041
# 1          9606       None  None  IC50    uM  UO_0000065        None    0.3
# 2          9606       None  None  IC50    uM  UO_0000065        None   7.82
# 3          9606       None  None  IC50    uM  UO_0000065        None   0.17

# %%
res = new_client.activity.filter(target_chembl_id=target_id).filter(standard_type="IC50")
df=pd.DataFrame.from_dict(res)
df.head(4)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        32260                  []    CHEMBL674637
# 1             None        32263                  []    CHEMBL621151
# 2             None        32265                  []    CHEMBL615325
# 3             None        32267                  []    CHEMBL674637
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity towards tyrosine phosphory...          B
# 1  Inhibition of autophosphorylation of human epi...          F
# 2  Inhibition of ligand-induced proliferation in ...          F
# 3  Inhibitory activity towards tyrosine phosphory...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000219
# 2                    None                   None  BAO_0000190  BAO_0000219
# 3                    None                   None  BAO_0000190  BAO_0000357
#
#                bao_label                                   canonical_smiles  \
# 0  single protein format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1      cell-based format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2      cell-based format  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3  single protein format  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
#
#   data_validity_comment data_validity_description document_chembl_id  \
# 0                  None                      None      CHEMBL1134862
# 1                  None                      None      CHEMBL1134862
# 2                  None                      None      CHEMBL1134862
# 3                  None                      None      CHEMBL1134862
#
#            document_journal  document_year  \
# 0  Bioorg. Med. Chem. Lett.         2002.0
# 1  Bioorg. Med. Chem. Lett.         2002.0
# 2  Bioorg. Med. Chem. Lett.         2002.0
# 3  Bioorg. Med. Chem. Lett.         2002.0
#
#                                    ligand_efficiency molecule_chembl_id  \
# 0  {'bei': '19.25', 'le': '0.37', 'lle': '2.94', ...        CHEMBL68920
# 1                                               None        CHEMBL68920
# 2                                               None        CHEMBL68920
# 3  {'bei': '14.02', 'le': '0.27', 'lle': '3.16', ...        CHEMBL69960
#
#   molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0               None               CHEMBL68920          7.39
# 1               None               CHEMBL68920          6.52
# 2               None               CHEMBL68920          5.11
# 3               None               CHEMBL69960          6.77
#
#    potential_duplicate                                 qudt_units  record_id  \
# 0                False  http://www.openphacts.org/units/Nanomolar     119482
# 1                False  http://www.openphacts.org/units/Nanomolar     119482
# 2                False  http://www.openphacts.org/units/Nanomolar     119482
# 3                False  http://www.openphacts.org/units/Nanomolar     119494
#
#   relation  src_id  standard_flag standard_relation standard_text_value  \
# 0        =       1           True                 =                None
# 1        =       1           True                 =                None
# 2        =       1           True                 =                None
# 3        =       1           True                 =                None
#
#   standard_type standard_units standard_upper_value standard_value  \
# 0          IC50             nM                 None           41.0
# 1          IC50             nM                 None          300.0
# 2          IC50             nM                 None         7820.0
# 3          IC50             nM                 None          170.0
#
#   target_chembl_id target_organism                        target_pref_name  \
# 0        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 1        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 2        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
# 3        CHEMBL203    Homo sapiens  Epidermal growth factor receptor erbB1
#
#   target_tax_id text_value  toid  type units    uo_units upper_value  value
# 0          9606       None  None  IC50    uM  UO_0000065        None  0.041
# 1          9606       None  None  IC50    uM  UO_0000065        None    0.3
# 2          9606       None  None  IC50    uM  UO_0000065        None   7.82
# 3          9606       None  None  IC50    uM  UO_0000065        None   0.17

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv("EGFR_bioactivity.csv", index=False)

# %%
! copy EGFR_bioactivity.csv cd
# Out:
#         1 file(s) copied.

# %%
#removing missing data
df2 = df[df.standard_value.notna()]
# Out:
#       activity_comment  activity_id  \
# 0                 None        32260
# 1                 None        32263
# 2                 None        32265
# 3                 None        32267
# 4                 None        32270
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 1                                                     []    CHEMBL621151
# 2                                                     []    CHEMBL615325
# 3                                                     []    CHEMBL674637
# 4                                                     []    CHEMBL621151
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format              bao_label  \
# 0      BAO_0000357  single protein format
# 1      BAO_0000219      cell-based format
# 2      BAO_0000219      cell-based format
# 3      BAO_0000357  single protein format
# 4      BAO_0000219      cell-based format
# ...            ...                    ...
# 15258  BAO_0000357  single protein format
# 15259  BAO_0000357  single protein format
# 15260  BAO_0000357  single protein format
# 15261  BAO_0000357  single protein format
# 15262  BAO_0000357  single protein format
#
#                                         canonical_smiles  \
# 0      Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1      Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2      Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3      Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4      Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                                                  ...
# 15258  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...
# 15259  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 15260  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 15261  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 15262  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#             data_validity_comment  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# ...                           ...
# 15258  Non standard unit for type
# 15259  Non standard unit for type
# 15260                        None
# 15261                        None
# 15262                        None
#
#                                data_validity_description document_chembl_id  \
# 0                                                   None      CHEMBL1134862
# 1                                                   None      CHEMBL1134862
# 2                                                   None      CHEMBL1134862
# 3                                                   None      CHEMBL1134862
# 4                                                   None      CHEMBL1134862
# ...                                                  ...                ...
# 15258  Units for this activity type are unusual and m...      CHEMBL4507273
# 15259  Units for this activity type are unusual and m...      CHEMBL4507292
# 15260                                               None      CHEMBL4507327
# 15261                                               None      CHEMBL4507326
# 15262                                               None      CHEMBL4507327
#
#                document_journal  document_year  \
# 0      Bioorg. Med. Chem. Lett.         2002.0
# 1      Bioorg. Med. Chem. Lett.         2002.0
# 2      Bioorg. Med. Chem. Lett.         2002.0
# 3      Bioorg. Med. Chem. Lett.         2002.0
# 4      Bioorg. Med. Chem. Lett.         2002.0
# ...                         ...            ...
# 15258                      None         2021.0
# 15259                      None         2021.0
# 15260                      None         2021.0
# 15261                      None         2021.0
# 15262                      None         2021.0
#
#                                        ligand_efficiency molecule_chembl_id  \
# 0      {'bei': '19.25', 'le': '0.37', 'lle': '2.94', ...        CHEMBL68920
# 1                                                   None        CHEMBL68920
# 2                                                   None        CHEMBL68920
# 3      {'bei': '14.02', 'le': '0.27', 'lle': '3.16', ...        CHEMBL69960
# 4                                                   None        CHEMBL69960
# ...                                                  ...                ...
# 15258                                               None      CHEMBL4520788
# 15259                                               None      CHEMBL1800685
# 15260                                               None      CHEMBL4088216
# 15261                                               None      CHEMBL4549667
# 15262                                               None      CHEMBL4097778
#
#       molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                   None               CHEMBL68920          7.39
# 1                   None               CHEMBL68920          6.52
# 2                   None               CHEMBL68920          5.11
# 3                   None               CHEMBL69960          6.77
# 4                   None               CHEMBL69960          7.40
# ...                  ...                       ...           ...
# 15258            BAY-294             CHEMBL4520788          None
# 15259               PPTN             CHEMBL1800685          None
# 15260           TP-030-1             CHEMBL4088216          None
# 15261           TP-030-2             CHEMBL4549667          None
# 15262            TP-030n             CHEMBL4097778          None
#
#        potential_duplicate                                 qudt_units  \
# 0                    False  http://www.openphacts.org/units/Nanomolar
# 1                    False  http://www.openphacts.org/units/Nanomolar
# 2                    False  http://www.openphacts.org/units/Nanomolar
# 3                    False  http://www.openphacts.org/units/Nanomolar
# 4                    False  http://www.openphacts.org/units/Nanomolar
# ...                    ...                                        ...
# 15258                False                                       None
# 15259                False                                       None
# 15260                False                                       None
# 15261                False                                       None
# 15262                False                                       None
#
#        record_id relation  src_id  standard_flag standard_relation  \
# 0         119482        =       1           True                 =
# 1         119482        =       1           True                 =
# 2         119482        =       1           True                 =
# 3         119494        =       1           True                 =
# 4         119494        =       1           True                 =
# ...          ...      ...     ...            ...               ...
# 15258    3359676        >      54          False                 >
# 15259    3359713     None      54          False              None
# 15260    3359782     None      54           True              None
# 15261    3359780     None      54           True              None
# 15262    3489319     None      54           True              None
#
#       standard_text_value standard_type standard_units standard_upper_value  \
# 0                    None          IC50             nM                 None
# 1                    None          IC50             nM                 None
# 2                    None          IC50             nM                 None
# 3                    None          IC50             nM                 None
# 4                    None          IC50             nM                 None
# ...                   ...           ...            ...                  ...
# 15258                None          IC50             µM                 None
# 15259                None          IC50             µM                 None
# 15260                None          IC50             nM                 None
# 15261                None          IC50             nM                 None
# 15262                None          IC50             nM                 None
#
#       standard_value target_chembl_id target_organism  \
# 0               41.0        CHEMBL203    Homo sapiens
# 1              300.0        CHEMBL203    Homo sapiens
# 2             7820.0        CHEMBL203    Homo sapiens
# 3              170.0        CHEMBL203    Homo sapiens
# 4               40.0        CHEMBL203    Homo sapiens
# ...              ...              ...             ...
# 15258           20.0        CHEMBL203    Homo sapiens
# 15259           4.59        CHEMBL203    Homo sapiens
# 15260         1000.0        CHEMBL203    Homo sapiens
# 15261         1000.0        CHEMBL203    Homo sapiens
# 15262         1000.0        CHEMBL203    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 1      Epidermal growth factor receptor erbB1          9606       None  None
# 2      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 4      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type units    uo_units upper_value  value
# 0       IC50    uM  UO_0000065        None  0.041
# 1       IC50    uM  UO_0000065        None    0.3
# 2       IC50    uM  UO_0000065        None   7.82
# 3       IC50    uM  UO_0000065        None   0.17
# 4       IC50    uM  UO_0000065        None   0.04
# ...      ...   ...         ...         ...    ...
# 15258   IC50    µM        None        None   20.0
# 15259   IC50    µM        None        None   4.59
# 15260  pIC50  None        None        None    6.0
# 15261  pIC50  None        None        None    6.0
# 15262  pIC50  None        None        None    6.0
#
# [13904 rows x 45 columns]

# %%
#drop duplicate molecules for simplicity
df2 = df2.drop_duplicates(subset="molecule_chembl_id")
df2
# Out:
#       activity_comment  activity_id  \
# 0                 None        32260
# 3                 None        32267
# 6                 None        32680
# 7                 None        32770
# 8                 None        32772
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 3                                                     []    CHEMBL674637
# 6                                                     []    CHEMBL677833
# 7                                                     []    CHEMBL674643
# 8                                                     []    CHEMBL674643
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 6      In vitro inhibition of Epidermal growth factor...          B
# 7      Inhibitory concentration of EGF dependent auto...          B
# 8      Inhibitory concentration of EGF dependent auto...          B
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 6                        None                   None  BAO_0000190
# 7                        None                   None  BAO_0000190
# 8                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format              bao_label  \
# 0      BAO_0000357  single protein format
# 3      BAO_0000357  single protein format
# 6      BAO_0000357  single protein format
# 7      BAO_0000357  single protein format
# 8      BAO_0000357  single protein format
# ...            ...                    ...
# 15258  BAO_0000357  single protein format
# 15259  BAO_0000357  single protein format
# 15260  BAO_0000357  single protein format
# 15261  BAO_0000357  single protein format
# 15262  BAO_0000357  single protein format
#
#                                         canonical_smiles  \
# 0      Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3      Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 6            CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12
# 7                 CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1
# 8                                 O=C(O)/C=C/c1ccc(O)cc1
# ...                                                  ...
# 15258  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...
# 15259  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 15260  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 15261  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 15262  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#             data_validity_comment  \
# 0                            None
# 3                            None
# 6                            None
# 7           Outside typical range
# 8           Outside typical range
# ...                           ...
# 15258  Non standard unit for type
# 15259  Non standard unit for type
# 15260                        None
# 15261                        None
# 15262                        None
#
#                                data_validity_description document_chembl_id  \
# 0                                                   None      CHEMBL1134862
# 3                                                   None      CHEMBL1134862
# 6                                                   None      CHEMBL1145114
# 7      Values for this activity type are unusually la...      CHEMBL1124610
# 8      Values for this activity type are unusually la...      CHEMBL1124610
# ...                                                  ...                ...
# 15258  Units for this activity type are unusual and m...      CHEMBL4507273
# 15259  Units for this activity type are unusual and m...      CHEMBL4507292
# 15260                                               None      CHEMBL4507327
# 15261                                               None      CHEMBL4507326
# 15262                                               None      CHEMBL4507327
#
#                document_journal  document_year  \
# 0      Bioorg. Med. Chem. Lett.         2002.0
# 3      Bioorg. Med. Chem. Lett.         2002.0
# 6                 J. Med. Chem.         2003.0
# 7                 J. Med. Chem.         1989.0
# 8                 J. Med. Chem.         1989.0
# ...                         ...            ...
# 15258                      None         2021.0
# 15259                      None         2021.0
# 15260                      None         2021.0
# 15261                      None         2021.0
# 15262                      None         2021.0
#
#                                        ligand_efficiency molecule_chembl_id  \
# 0      {'bei': '19.25', 'le': '0.37', 'lle': '2.94', ...        CHEMBL68920
# 3      {'bei': '14.02', 'le': '0.27', 'lle': '3.16', ...        CHEMBL69960
# 6      {'bei': '13.62', 'le': '0.25', 'lle': '0.26', ...       CHEMBL137635
# 7                                                   None       CHEMBL306988
# 8                                                   None        CHEMBL66879
# ...                                                  ...                ...
# 15258                                               None      CHEMBL4520788
# 15259                                               None      CHEMBL1800685
# 15260                                               None      CHEMBL4088216
# 15261                                               None      CHEMBL4549667
# 15262                                               None      CHEMBL4097778
#
#       molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                   None               CHEMBL68920          7.39
# 3                   None               CHEMBL69960          6.77
# 6                   None              CHEMBL137635          5.03
# 7                   None              CHEMBL306988          None
# 8          COUMARIC ACID               CHEMBL66879          None
# ...                  ...                       ...           ...
# 15258            BAY-294             CHEMBL4520788          None
# 15259               PPTN             CHEMBL1800685          None
# 15260           TP-030-1             CHEMBL4088216          None
# 15261           TP-030-2             CHEMBL4549667          None
# 15262            TP-030n             CHEMBL4097778          None
#
#        potential_duplicate                                 qudt_units  \
# 0                    False  http://www.openphacts.org/units/Nanomolar
# 3                    False  http://www.openphacts.org/units/Nanomolar
# 6                    False  http://www.openphacts.org/units/Nanomolar
# 7                    False  http://www.openphacts.org/units/Nanomolar
# 8                    False  http://www.openphacts.org/units/Nanomolar
# ...                    ...                                        ...
# 15258                False                                       None
# 15259                False                                       None
# 15260                False                                       None
# 15261                False                                       None
# 15262                False                                       None
#
#        record_id relation  src_id  standard_flag standard_relation  \
# 0         119482        =       1           True                 =
# 3         119494        =       1           True                 =
# 6         262238        =       1           True                 =
# 7         137177        =       1           True                 =
# 8         137215        =       1           True                 =
# ...          ...      ...     ...            ...               ...
# 15258    3359676        >      54          False                 >
# 15259    3359713     None      54          False              None
# 15260    3359782     None      54           True              None
# 15261    3359780     None      54           True              None
# 15262    3489319     None      54           True              None
#
#       standard_text_value standard_type standard_units standard_upper_value  \
# 0                    None          IC50             nM                 None
# 3                    None          IC50             nM                 None
# 6                    None          IC50             nM                 None
# 7                    None          IC50             nM                 None
# 8                    None          IC50             nM                 None
# ...                   ...           ...            ...                  ...
# 15258                None          IC50             µM                 None
# 15259                None          IC50             µM                 None
# 15260                None          IC50             nM                 None
# 15261                None          IC50             nM                 None
# 15262                None          IC50             nM                 None
#
#       standard_value target_chembl_id target_organism  \
# 0               41.0        CHEMBL203    Homo sapiens
# 3              170.0        CHEMBL203    Homo sapiens
# 6             9300.0        CHEMBL203    Homo sapiens
# 7           500000.0        CHEMBL203    Homo sapiens
# 8          3000000.0        CHEMBL203    Homo sapiens
# ...              ...              ...             ...
# 15258           20.0        CHEMBL203    Homo sapiens
# 15259           4.59        CHEMBL203    Homo sapiens
# 15260         1000.0        CHEMBL203    Homo sapiens
# 15261         1000.0        CHEMBL203    Homo sapiens
# 15262         1000.0        CHEMBL203    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 6      Epidermal growth factor receptor erbB1          9606       None  None
# 7      Epidermal growth factor receptor erbB1          9606       None  None
# 8      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type units    uo_units upper_value   value
# 0       IC50    uM  UO_0000065        None   0.041
# 3       IC50    uM  UO_0000065        None    0.17
# 6       IC50    uM  UO_0000065        None     9.3
# 7       IC50    uM  UO_0000065        None   500.0
# 8       IC50    uM  UO_0000065        None  3000.0
# ...      ...   ...         ...         ...     ...
# 15258   IC50    µM        None        None    20.0
# 15259   IC50    µM        None        None    4.59
# 15260  pIC50  None        None        None     6.0
# 15261  pIC50  None        None        None     6.0
# 15262  pIC50  None        None        None     6.0
#
# [8922 rows x 45 columns]

# %%
#set bioactivity level based on standard value

bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
#construct new dataframe with molecule_chembl_id, canonical_smiles, and standard_value

selection = ["molecule_chembl_id", "canonical_smiles", "standard_value"]
df3 = df2[selection]
df3 = df3.reset_index()
df3
# Out:
#       index molecule_chembl_id  \
# 0         0        CHEMBL68920
# 1         3        CHEMBL69960
# 2         6       CHEMBL137635
# 3         7       CHEMBL306988
# 4         8        CHEMBL66879
# ...     ...                ...
# 8917  15258      CHEMBL4520788
# 8918  15259      CHEMBL1800685
# 8919  15260      CHEMBL4088216
# 8920  15261      CHEMBL4549667
# 8921  15262      CHEMBL4097778
#
#                                        canonical_smiles standard_value
# 0     Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...           41.0
# 1     Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...          170.0
# 2           CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12         9300.0
# 3                CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1       500000.0
# 4                                O=C(O)/C=C/c1ccc(O)cc1      3000000.0
# ...                                                 ...            ...
# 8917  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...           20.0
# 8918  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...           4.59
# 8919  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...         1000.0
# 8920  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...         1000.0
# 8921  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...         1000.0
#
# [8922 rows x 4 columns]

# %%
#add bioactivity_class to df3
df3 = pd.concat([df3,pd.Series(bioactivity_class).rename("bioactivity_class")], axis=1)
df3
# Out:
#       index molecule_chembl_id  \
# 0         0        CHEMBL68920
# 1         3        CHEMBL69960
# 2         6       CHEMBL137635
# 3         7       CHEMBL306988
# 4         8        CHEMBL66879
# ...     ...                ...
# 8917  15258      CHEMBL4520788
# 8918  15259      CHEMBL1800685
# 8919  15260      CHEMBL4088216
# 8920  15261      CHEMBL4549667
# 8921  15262      CHEMBL4097778
#
#                                        canonical_smiles standard_value  \
# 0     Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...           41.0
# 1     Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...          170.0
# 2           CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12         9300.0
# 3                CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1       500000.0
# 4                                O=C(O)/C=C/c1ccc(O)cc1      3000000.0
# ...                                                 ...            ...
# 8917  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...           20.0
# 8918  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...           4.59
# 8919  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...         1000.0
# 8920  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...         1000.0
# 8921  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...         1000.0
#
#      bioactivity_class
# 0               active
# 1               active
# 2         intermediate
# 3             inactive
# 4             inactive
# ...                ...
# 8917            active
# 8918            active
# 8919            active
# 8920            active
# 8921            active
#
# [8922 rows x 5 columns]

# %%
df3.to_csv("EGFR_bioactivity_preprocessed.csv", index=False)

# %%
! copy EGFR_bioactivity_preprocessed.csv cd
# Out:
#         1 file(s) copied.

# %%
import numpy as np

# %%
# !wsl
# Out:
# ^C

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh\
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
